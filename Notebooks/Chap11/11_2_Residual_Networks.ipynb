# %% [markdown]
# <a href="https://colab.research.google.com/github/venkateswararaoganguru-hue/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-75hsgscv
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-75hsgscv
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=1bf768a354b86405dbc10215302cff8b815d998ddc505c24c50060e831f06b3f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k7e2bqix/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x)

    h2 = h1 + self.linear2(h1.relu())

    h3 = h2 + self.linear3(h2.relu())

    return self.linear4(h3.relu())

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.584171, train error 61.22,  val loss 1.687280, percent error 69.00
# Epoch     1, train loss 1.310344, train error 48.65,  val loss 1.470533, percent error 59.90
# Epoch     2, train loss 1.136615, train error 42.50,  val loss 1.358391, percent error 55.90
# Epoch     3, train loss 0.928296, train error 34.07,  val loss 1.204047, percent error 47.90
# Epoch     4, train loss 0.800957, train error 28.60,  val loss 1.169129, percent error 46.90
# Epoch     5, train loss 0.726279, train error 25.78,  val loss 1.198015, percent error 43.90
# Epoch     6, train loss 0.617915, train error 21.78,  val loss 1.149256, percent error 43.40
# Epoch     7, train loss 0.543342, train error 19.18,  val loss 1.175641, percent error 42.60
# Epoch     8, train loss 0.480663, train error 16.72,  val loss 1.202930, percent error 43.60
# Epoch     9, train loss 0.419938, train error 14.40,  val loss 1.180134, percent error 40.90
# Epoch    10, train loss 0.340000, train error 11.72,  val loss 1.164494, percent error 37.70
# Epoch    11, train loss 0.276256, train error 8.55,  val loss 1.217894, percent error 37.50
# Epoch    12, train loss 0.216010, train error 6.62,  val loss 1.242584, percent error 37.50
# Epoch    13, train loss 0.251197, train error 8.45,  val loss 1.348268, percent error 38.70
# Epoch    14, train loss 0.185444, train error 5.75,  val loss 1.325814, percent error 38.30
# Epoch    15, train loss 0.204188, train error 6.57,  val loss 1.306757, percent error 36.10
# Epoch    16, train loss 0.159528, train error 5.00,  val loss 1.395841, percent error 37.00
# Epoch    17, train loss 0.111907, train error 3.10,  val loss 1.392866, percent error 36.40
# Epoch    18, train loss 0.094873, train error 2.47,  val loss 1.462620, percent error 37.50
# Epoch    19, train loss 0.093041, train error 2.57,  val loss 1.552722, percent error 34.90
# Epoch    20, train loss 0.030646, train error 0.15,  val loss 1.451717, percent error 33.60
# Epoch    21, train loss 0.018708, train error 0.05,  val loss 1.431630, percent error 33.00
# Epoch    22, train loss 0.013824, train error 0.00,  val loss 1.444318, percent error 33.60
# Epoch    23, train loss 0.011704, train error 0.00,  val loss 1.465401, percent error 32.80
# Epoch    24, train loss 0.010412, train error 0.00,  val loss 1.488621, percent error 32.90
# Epoch    25, train loss 0.009186, train error 0.00,  val loss 1.499517, percent error 32.70
# Epoch    26, train loss 0.008380, train error 0.00,  val loss 1.523682, percent error 32.40
# Epoch    27, train loss 0.007686, train error 0.00,  val loss 1.536747, percent error 32.90
# Epoch    28, train loss 0.007146, train error 0.00,  val loss 1.552421, percent error 32.70
# Epoch    29, train loss 0.006735, train error 0.00,  val loss 1.566596, percent error 33.00
# Epoch    30, train loss 0.006214, train error 0.00,  val loss 1.573504, percent error 32.80
# Epoch    31, train loss 0.005840, train error 0.00,  val loss 1.588676, percent error 32.80
# Epoch    32, train loss 0.005512, train error 0.00,  val loss 1.597236, percent error 32.70
# Epoch    33, train loss 0.005282, train error 0.00,  val loss 1.610429, percent error 33.00
# Epoch    34, train loss 0.004977, train error 0.00,  val loss 1.622782, percent error 32.80
# Epoch    35, train loss 0.004734, train error 0.00,  val loss 1.629556, percent error 32.70
# Epoch    36, train loss 0.004518, train error 0.00,  val loss 1.641517, percent error 32.80
# Epoch    37, train loss 0.004316, train error 0.00,  val loss 1.647647, percent error 32.70
# Epoch    38, train loss 0.004133, train error 0.00,  val loss 1.656350, percent error 32.70
# Epoch    39, train loss 0.003968, train error 0.00,  val loss 1.666116, percent error 32.80
# Epoch    40, train loss 0.003881, train error 0.00,  val loss 1.668847, percent error 32.70
# Epoch    41, train loss 0.003805, train error 0.00,  val loss 1.673393, percent error 32.70
# Epoch    42, train loss 0.003733, train error 0.00,  val loss 1.677069, percent error 32.70
# Epoch    43, train loss 0.003664, train error 0.00,  val loss 1.681816, percent error 32.90
# Epoch    44, train loss 0.003597, train error 0.00,  val loss 1.685135, percent error 32.70
# Epoch    45, train loss 0.003536, train error 0.00,  val loss 1.687618, percent error 32.60
# Epoch    46, train loss 0.003473, train error 0.00,  val loss 1.692087, percent error 32.70
# Epoch    47, train loss 0.003413, train error 0.00,  val loss 1.695030, percent error 32.50
# Epoch    48, train loss 0.003357, train error 0.00,  val loss 1.699121, percent error 32.70
# Epoch    49, train loss 0.003300, train error 0.00,  val loss 1.702232, percent error 32.60
# Epoch    50, train loss 0.003247, train error 0.00,  val loss 1.704665, percent error 32.70
# Epoch    51, train loss 0.003195, train error 0.00,  val loss 1.709825, percent error 32.60
# Epoch    52, train loss 0.003144, train error 0.00,  val loss 1.712289, percent error 32.70
# Epoch    53, train loss 0.003096, train error 0.00,  val loss 1.716141, percent error 32.60
# Epoch    54, train loss 0.003048, train error 0.00,  val loss 1.718352, percent error 32.60
# Epoch    55, train loss 0.003002, train error 0.00,  val loss 1.721537, percent error 32.60
# Epoch    56, train loss 0.002957, train error 0.00,  val loss 1.724868, percent error 32.60
# Epoch    57, train loss 0.002914, train error 0.00,  val loss 1.728624, percent error 32.60
# Epoch    58, train loss 0.002872, train error 0.00,  val loss 1.730569, percent error 32.60
# Epoch    59, train loss 0.002831, train error 0.00,  val loss 1.732729, percent error 32.60
# Epoch    60, train loss 0.002810, train error 0.00,  val loss 1.734572, percent error 32.60
# Epoch    61, train loss 0.002790, train error 0.00,  val loss 1.735833, percent error 32.60
# Epoch    62, train loss 0.002772, train error 0.00,  val loss 1.738294, percent error 32.50
# Epoch    63, train loss 0.002752, train error 0.00,  val loss 1.739405, percent error 32.60
# Epoch    64, train loss 0.002733, train error 0.00,  val loss 1.740495, percent error 32.60
# Epoch    65, train loss 0.002714, train error 0.00,  val loss 1.741977, percent error 32.60
# Epoch    66, train loss 0.002696, train error 0.00,  val loss 1.743627, percent error 32.50
# Epoch    67, train loss 0.002678, train error 0.00,  val loss 1.745093, percent error 32.60
# Epoch    68, train loss 0.002659, train error 0.00,  val loss 1.746628, percent error 32.60
# Epoch    69, train loss 0.002642, train error 0.00,  val loss 1.748111, percent error 32.60
# Epoch    70, train loss 0.002624, train error 0.00,  val loss 1.749702, percent error 32.70
# Epoch    71, train loss 0.002607, train error 0.00,  val loss 1.750808, percent error 32.60
# Epoch    72, train loss 0.002590, train error 0.00,  val loss 1.751996, percent error 32.50
# Epoch    73, train loss 0.002573, train error 0.00,  val loss 1.753008, percent error 32.70
# Epoch    74, train loss 0.002556, train error 0.00,  val loss 1.754815, percent error 32.60
# Epoch    75, train loss 0.002540, train error 0.00,  val loss 1.756376, percent error 32.70
# Epoch    76, train loss 0.002524, train error 0.00,  val loss 1.757824, percent error 32.60
# Epoch    77, train loss 0.002508, train error 0.00,  val loss 1.758608, percent error 32.70
# Epoch    78, train loss 0.002492, train error 0.00,  val loss 1.760291, percent error 32.70
# Epoch    79, train loss 0.002476, train error 0.00,  val loss 1.760795, percent error 32.60
# Epoch    80, train loss 0.002468, train error 0.00,  val loss 1.762040, percent error 32.70
# Epoch    81, train loss 0.002460, train error 0.00,  val loss 1.762674, percent error 32.60
# Epoch    82, train loss 0.002453, train error 0.00,  val loss 1.763371, percent error 32.60
# Epoch    83, train loss 0.002445, train error 0.00,  val loss 1.763909, percent error 32.60
# Epoch    84, train loss 0.002438, train error 0.00,  val loss 1.764422, percent error 32.60
# Epoch    85, train loss 0.002430, train error 0.00,  val loss 1.764967, percent error 32.70
# Epoch    86, train loss 0.002423, train error 0.00,  val loss 1.765880, percent error 32.60
# Epoch    87, train loss 0.002415, train error 0.00,  val loss 1.766438, percent error 32.60
# Epoch    88, train loss 0.002408, train error 0.00,  val loss 1.767213, percent error 32.60
# Epoch    89, train loss 0.002401, train error 0.00,  val loss 1.767853, percent error 32.60
# Epoch    90, train loss 0.002393, train error 0.00,  val loss 1.768393, percent error 32.60
# Epoch    91, train loss 0.002386, train error 0.00,  val loss 1.769082, percent error 32.60
# Epoch    92, train loss 0.002379, train error 0.00,  val loss 1.769542, percent error 32.60
# Epoch    93, train loss 0.002372, train error 0.00,  val loss 1.770172, percent error 32.60
# Epoch    94, train loss 0.002364, train error 0.00,  val loss 1.770843, percent error 32.60
# Epoch    95, train loss 0.002357, train error 0.00,  val loss 1.771492, percent error 32.60
# Epoch    96, train loss 0.002350, train error 0.00,  val loss 1.772368, percent error 32.60
# Epoch    97, train loss 0.002343, train error 0.00,  val loss 1.772677, percent error 32.60
# Epoch    98, train loss 0.002337, train error 0.00,  val loss 1.773453, percent error 32.60
# Epoch    99, train loss 0.002329, train error 0.00,  val loss 1.774147, percent error 32.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
